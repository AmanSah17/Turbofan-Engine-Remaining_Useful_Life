# %%
import pandas as pd

# %%
DATASET_NAMES = ["FD001", "FD002", "FD003", "FD004"]

TRAIN_DATA_FILES = [("CMaps/train_{}.txt", format(x), x) for x in DATASET_NAMES]
TEST_DATA_FILES = [("CMaps/test_{}.txt", format(x), x) for x in DATASET_NAMES]

TEST_DATA_RUL_FILES = [("CMapas/RUL_{}.txt", format(x), x) for x in DATASET_NAMES]

OP_SETTING_COLUMNS = ["op_setting_{}".format(x) for x in range(1, 4)]
SENSOR_COLUMNS = ["sensor_{}".format(x) for x in range(1, 22)]

# %%
df = pd.read_csv("CMaps/train_FD001.txt", sep="\s+", header=None)
# df.head(20)


def read_data(filename):
    col_names = ["unit", "time_cycles"] + OP_SETTING_COLUMNS + SENSOR_COLUMNS
    return pd.read_csv(filename, sep="\s+", header=None, names=col_names)


train_FD001 = read_data("CMaps/train_FD001.txt")
train_FD001
# Out:
#        unit  time_cycles  op_setting_1  op_setting_2  op_setting_3  sensor_1  \
# 0         1            1       -0.0007       -0.0004         100.0    518.67
# 1         1            2        0.0019       -0.0003         100.0    518.67
# 2         1            3       -0.0043        0.0003         100.0    518.67
# 3         1            4        0.0007        0.0000         100.0    518.67
# 4         1            5       -0.0019       -0.0002         100.0    518.67
# ...     ...          ...           ...           ...           ...       ...
# 20626   100          196       -0.0004       -0.0003         100.0    518.67
# 20627   100          197       -0.0016       -0.0005         100.0    518.67
# 20628   100          198        0.0004        0.0000         100.0    518.67
# 20629   100          199       -0.0011        0.0003         100.0    518.67
# 20630   100          200       -0.0032       -0.0005         100.0    518.67
#
#        sensor_2  sensor_3  sensor_4  sensor_5  ...  sensor_12  sensor_13  \
# 0        641.82   1589.70   1400.60     14.62  ...     521.66    2388.02
# 1        642.15   1591.82   1403.14     14.62  ...     522.28    2388.07
# 2        642.35   1587.99   1404.20     14.62  ...     522.42    2388.03
# 3        642.35   1582.79   1401.87     14.62  ...     522.86    2388.08
# 4        642.37   1582.85   1406.22     14.62  ...     522.19    2388.04
# ...         ...       ...       ...       ...  ...        ...        ...
# 20626    643.49   1597.98   1428.63     14.62  ...     519.49    2388.26
# 20627    643.54   1604.50   1433.58     14.62  ...     519.68    2388.22
# 20628    643.42   1602.46   1428.18     14.62  ...     520.01    2388.24
# 20629    643.23   1605.26   1426.53     14.62  ...     519.67    2388.23
# 20630    643.85   1600.38   1432.14     14.62  ...     519.30    2388.26
#
#        sensor_14  sensor_15  sensor_16  sensor_17  sensor_18  sensor_19  \
# 0        8138.62     8.4195       0.03        392       2388      100.0
# 1        8131.49     8.4318       0.03        392       2388      100.0
# 2        8133.23     8.4178       0.03        390       2388      100.0
# 3        8133.83     8.3682       0.03        392       2388      100.0
# 4        8133.80     8.4294       0.03        393       2388      100.0
# ...          ...        ...        ...        ...        ...        ...
# 20626    8137.60     8.4956       0.03        397       2388      100.0
# 20627    8136.50     8.5139       0.03        395       2388      100.0
# 20628    8141.05     8.5646       0.03        398       2388      100.0
# 20629    8139.29     8.5389       0.03        395       2388      100.0
# 20630    8137.33     8.5036       0.03        396       2388      100.0
#
#        sensor_20  sensor_21
# 0          39.06    23.4190
# 1          39.00    23.4236
# 2          38.95    23.3442
# 3          38.88    23.3739
# 4          38.90    23.4044
# ...          ...        ...
# 20626      38.49    22.9735
# 20627      38.30    23.1594
# 20628      38.44    22.9333
# 20629      38.29    23.0640
# 20630      38.37    23.0522
#
# [20631 rows x 26 columns]

# %%
### Import the necessary modules

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.optimizers import Adam
import tensorflow.keras.backend as K
import tensorflow as tf
import matplotlib.pyplot as plt
import os

# %% [markdown]
# # -----------------------------
# # 1. Constants and Configs
# # -----------------------------

# %%
DATA_PATH = "CMaps/train_FD001.txt"
OP_COLS = ["op1", "op2", "op3"]
SENSOR_COLS = [f"sensor{i}" for i in range(1, 22)]  # sensors 1 to 21
ALL_COLUMNS = ["unit", "time_cycles"] + OP_COLS + SENSOR_COLS


SEQUENCE_LENGTH = 30

# %% [markdown]
# ### Lets Create our Loss function .
#     # According to the paper Damage Propogation Modelling read here ("Damage Propagation Modeling.pdf")
#     # we can create our Custom Asymmetric PHM08 Loss

# %%
def asymmetric_loss(y_true, y_pred):
    error = y_pred - y_true
    mask = K.cast(K.less(error, 0.0), K.floatx())
    loss_early = K.exp(-error / 13.0) - 1
    loss_rate = K.exp(error / 10) - 1
    return K.mean(mask * loss_early + (1 - mask) * loss_rate)

# %% [markdown]
# # -----------------------------
# # 3. Load and Preprocess Data
# # -----------------------------

# %%
print(ALL_COLUMNS)
# Out:
# ['unit', 'time_cycles', 'op1', 'op2', 'op3', 'sensor1', 'sensor2', 'sensor3', 'sensor4', 'sensor5', 'sensor6', 'sensor7', 'sensor8', 'sensor9', 'sensor10', 'sensor11', 'sensor12', 'sensor13', 'sensor14', 'sensor15', 'sensor16', 'sensor17', 'sensor18', 'sensor19', 'sensor20', 'sensor21']

# %%
def load_and_preprocess_data(filepath):
    df = pd.read_csv(filepath, sep="\s+", header=None, names=ALL_COLUMNS)

    # Compute RUL
    df["max_cycle"] = df.groupby("unit")["time_cycles"].transform("max")
    df["RUL"] = df["max_cycle"] - df["time_cycles"]
    df.drop("max_cycle", axis=1, inplace=True)

    return df

# %% [markdown]
# ### Now lets normalize the data present in all the feature columns.

# %%
def normalize(df, feature_columns):
    scaler = MinMaxScaler()
    df[feature_columns] = scaler.fit_transform(df[feature_columns])
    return df, scaler

# %% [markdown]
# # -----------------------------
# # 4. Sequence Builder
# # -----------------------------

# %%
def create_sequences(df, sequence_length, feature_columns):
    sequences = []
    rul_values = []

    for unit in df["unit"].unique():
        unit_df = df[df["unit"] == unit]
        unit_df = unit_df.reset_index(drop=True)
        for i in range(len(unit_df) - sequence_length + 1):
            seq = unit_df.loc[i : i + sequence_length - 1, feature_columns].values
            label = unit_df.loc[i + sequence_length - 1, "RUL"]
            sequences.append(seq)
            rul_values.append(label)

    X = np.array(sequences)
    y = np.array(rul_values).reshape(-1, 1)

    return X, y

# %% [markdown]
# # -----------------------------
# # 5. Build LSTM Model
# # -----------------------------

# %%
def base_lstm_model(input_shape):
    model = Sequential()
    model.add(LSTM(64, return_sequences=True, input_shape=input_shape))
    model.add(Dropout(0.3))
    model.add(LSTM(32))
    model.add(Dropout(0.3))
    model.add(Dense(1))

    model.compile(
        optimizer=Adam(learning_rate=0.00012),
        loss=asymmetric_loss,
        metrics=[
            tf.keras.metrics.MeanAbsoluteError(),
            tf.keras.metrics.AUC(),
            tf.keras.metrics.Accuracy(),
            tf.keras.metrics.LogCoshError(),
            tf.keras.metrics.MeanSquaredError(),
            tf.keras.metrics.R2Score(),
        ],
    )
    return model

# %%
base_lstm_model
# Out:
# <function __main__.base_lstm_model(input_shape)>

# %% [markdown]
# # -----------------------------
# # 6. Train the Model
# # -----------------------------

# %%
def train_model(model, X_train, y_train, epochs=50, batch_size=8):
    history = model.fit(
        X_train,
        y_train,
        validation_split=0.2,
        epochs=epochs,
        batch_size=batch_size,
        verbose=1,
    )
    return history

# %% [markdown]
# # -----------------------------
# # 7. Plot Training History
# # -----------------------------

# %%
def plot_loss(history):
    plt.plot(history.history["loss"], label="Train Loss")
    plt.plot(history.history["val_loss"], label="Val Loss")
    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    plt.title("Training Loss Curve")
    plt.legend()
    plt.grid()
    plt.show()

# %%
def main():
    # Step 1: Load data from the filepath
    print("📥 Loading data...")
    df = load_and_preprocess_data(DATA_PATH)

    # Step 2: Data Preprocessing
    feature_columns = OP_COLS + SENSOR_COLS
    df, scaler = normalize(df, feature_columns)

    # Step 3: Create sequences for LSTM
    print("🔁 Creating sequences...")
    X, y = create_sequences(df, SEQUENCE_LENGTH, feature_columns)

    print(f"✅ Input shape to LSTM: {X.shape}")  # Should be (samples, 30, features)
    print(f"✅ Target shape: {y.shape}")  # Should be (samples, 1)

    # Step 4: Build model
    model = base_lstm_model(input_shape=(SEQUENCE_LENGTH, len(feature_columns)))
    model.summary()

    # Step 5: Train
    print("🚀 Training LSTM model with asymmetric PHM08 loss...")
    history = train_model(model, X, y)

    # Step 6: Visualize
    plot_loss(history)

    # Step 7: Save

    model.save("base_rul_LSTM_0.h5")
    print("💾 Model saved as 'base_rul_LSTM_0.h5")


# -----------------------------
# 9. Run Main
# -----------------------------
if __name__ == "__main__":
    main()
# Out:
# 📥 Loading data...
# 🔁 Creating sequences...
# ✅ Input shape to LSTM: (17731, 30, 24)
# ✅ Target shape: (17731, 1)
# d:\turbofan_RUL\Turbofan-Engine-Remaining_Useful_Life\tf_rul\lib\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 30, 64)         │        22,784 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 30, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 32)             │        12,416 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 35,233 (137.63 KB)
#  Trainable params: 35,233 (137.63 KB)
#  Non-trainable params: 0 (0.00 B)
# 🚀 Training LSTM model with asymmetric PHM08 loss...
# Epoch 1/50
# 1773/1773 ━━━━━━━━━━━━━━━━━━━━ 20s 10ms/step - accuracy: 0.0000e+00 - auc: 0.4657 - logcosh: 88.6869 - loss: 114532080.0000 - mean_absolute_error: 89.3758 - mean_squared_error: 11413.2959 - r2_score: -2.3299 - val_accuracy: 0.0000e+00 - val_auc: 0.5000 - val_logcosh: 99.6888 - val_loss: 101601456.0000 - val_mean_absolute_error: 100.3769 - val_mean_squared_error: 15226.9932 - val_r2_score: -1.9302
# Epoch 2/50
# 1773/1773 ━━━━━━━━━━━━━━━━━━━━ 17s 10ms/step - accuracy: 0.0000e+00 - auc: 0.4969 - logcosh: 84.0661 - loss: 59521584.0000 - mean_absolute_error: 84.7546 - mean_squared_error: 10512.9150 - r2_score: -2.1159 - val_accuracy: 0.0000e+00 - val_auc: 0.5000 - val_logcosh: 97.9018 - val_loss: 87463896.0000 - val_mean_absolute_error: 98.5899 - val_mean_squared_error: 14841.0615 - val_r2_score: -1.8559
# Epoch 3/50
# 1773/1773 ━━━━━━━━━━━━━━━━━━━━ 17s 10ms/step - accuracy: 0.0000e+00 - auc: 0.4994 - logcosh: 82.2293 - loss: 65970504.0000 - mean_absolute_error: 82.9180 - mean_squared_error: 10229.3486 - r2_score: -1.9850 - val_accuracy: 0.0000e+00 - val_auc: 0.5000 - val_logcosh: 96.9576 - val_loss: 80701808.0000 - val_mean_absolute_error: 97.6455 - val_mean_squared_error: 14636.7803 - val_r2_score: -1.8166
# Epoch 4/50
# 1773/1773 ━━━━━━━━━━━━━━━━━━━━ 17s 10ms/step - accuracy: 0.0000e+00 - auc: 0.4977 - logcosh: 82.0153 - loss: 51013144.0000 - mean_absolute_error: 82.7042 - mean_squared_error: 10132.7529 - r2_score: -2.0023 - val_accuracy: 0.0000e+00 - val_auc: 0.5000 - val_logcosh: 96.2403 - val_loss: 75869968.0000 - val_mean_absolute_error: 96.9292 - val_mean_squared_error: 14481.4863 - val_r2_score: -1.7867
# Epoch 5/50
# 1773/1773 ━━━━━━━━━━━━━━━━━━━━ 17s 10ms/step - accuracy: 0.0000e+00 - auc: 0.4927 - logcosh: 81.8329 - loss: 53988036.0000 - mean_absolute_error: 82.5219 - mean_squared_error: 10200.5938 - r2_score: -1.9248 - val_accuracy: 0.0000e+00 - val_auc: 0.5000 - val_logcosh: 95.5980 - val_loss: 71751136.0000 - val_mean_absolute_error: 96.2876 - val_mean_squared_error: 14342.1807 - val_r2_score: -1.7599
# Epoch 6/50
# 1773/1773 ━━━━━━━━━━━━━━━━━━━━ 16s 9ms/step - accuracy: 0.0000e+00 - auc: 0.4983 - logcosh: 80.0827 - loss: 50715180.0000 - mean_absolute_error: 80.7712 - mean_squared_error: 9820.3516 - r2_score: -1.8831 - val_accuracy: 0.0000e+00 - val_auc: 0.5000 - val_logcosh: 94.9617 - val_loss: 67858128.0000 - val_mean_absolute_error: 95.6503 - val_mean_squared_error: 14203.9941 - val_r2_score: -1.7333
# Epoch 7/50
# 1773/1773 ━━━━━━━━━━━━━━━━━━━━ 16s 9ms/step - accuracy: 0.0000e+00 - auc: 0.4935 - logcosh: 79.5031 - loss: 57775360.0000 - mean_absolute_error: 80.1919 - mean_squared_error: 9731.8359 - r2_score: -1.8346 - val_accuracy: 0.0000e+00 - val_auc: 0.5000 - val_logcosh: 94.3688 - val_loss: 64392932.0000 - val_mean_absolute_error: 95.0568 - val_mean_squared_error: 14075.1318 - val_r2_score: -1.7085
# Epoch 8/50
# 1773/1773 ━━━━━━━━━━━━━━━━━━━━ 16s 9ms/step - accuracy: 0.0000e+00 - auc: 0.4955 - logcosh: 79.0767 - loss: 53336016.0000 - mean_absolute_error: 79.7650 - mean_squared_error: 9682.6084 - r2_score: -1.7922 - val_accuracy: 0.0000e+00 - val_auc: 0.5000 - val_logcosh: 93.7466 - val_loss: 60916428.0000 - val_mean_absolute_error: 94.4353 - val_mean_squared_error: 13939.6846 - val_r2_score: -1.6825
# Epoch 9/50
# 1773/1773 ━━━━━━━━━━━━━━━━━━━━ 16s 9ms/step - accuracy: 0.0000e+00 - auc: 0.4977 - logcosh: 79.5308 - loss: 81329640.0000 - mean_absolute_error: 80.2194 - mean_squared_error: 9743.0908 - r2_score: -1.8155 - val_accuracy: 0.0000e+00 - val_auc: 0.5000 - val_logcosh: 93.1844 - val_loss: 57915240.0000 - val_mean_absolute_error: 93.8740 - val_mean_squared_error: 13817.2871 - val_r2_score: -1.6589
# Epoch 10/50
# 1773/1773 ━━━━━━━━━━━━━━━━━━━━ 16s 9ms/step - accuracy: 0.0000e+00 - auc: 0.4986 - logcosh: 77.3940 - loss: 35142376.0000 - mean_absolute_error: 78.0822 - mean_squared_error: 9391.4551 - r2_score: -1.7082 - val_accuracy: 0.0000e+00 - val_auc: 0.5000 - val_logcosh: 92.5057 - val_loss: 54454208.0000 - val_mean_absolute_error: 93.1947 - val_mean_squared_error: 13669.1699 - val_r2_score: -1.6304
# Epoch 11/50
# 1773/1773 ━━━━━━━━━━━━━━━━━━━━ 16s 9ms/step - accuracy: 0.0000e+00 - auc: 0.4958 - logcosh: 78.2168 - loss: 40961696.0000 - mean_absolute_error: 78.9050 - mean_squared_error: 9525.1943 - r2_score: -1.7402 - val_accuracy: 0.0000e+00 - val_auc: 0.5000 - val_logcosh: 91.9340 - val_loss: 51674716.0000 - val_mean_absolute_error: 92.6224 - val_mean_squared_error: 13544.2520 - val_r2_score: -1.6064
# Epoch 12/50
# 1773/1773 ━━━━━━━━━━━━━━━━━━━━ 16s 9ms/step - accuracy: 0.0000e+00 - auc: 0.4769 - logcosh: 77.5160 - loss: 34859632.0000 - mean_absolute_error: 78.2054 - mean_squared_error: 9294.9941 - r2_score: -1.7501 - val_accuracy: 0.0000e+00 - val_auc: 0.5000 - val_logcosh: 91.3898 - val_loss: 49138620.0000 - val_mean_absolute_error: 92.0788 - val_mean_squared_error: 13425.1494 - val_r2_score: -1.5835
# Epoch 13/50
# 1773/1773 ━━━━━━━━━━━━━━━━━━━━ 16s 9ms/step - accuracy: 0.0000e+00 - auc: 0.4969 - logcosh: 77.3986 - loss: 44481924.0000 - mean_absolute_error: 78.0874 - mean_squared_error: 9369.8037 - r2_score: -1.6817 - val_accuracy: 0.0000e+00 - val_auc: 0.5000 - val_logcosh: 90.8313 - val_loss: 46648168.0000 - val_mean_absolute_error: 91.5204 - val_mean_squared_error: 13302.9287 - val_r2_score: -1.5599
# Epoch 14/50
# 1773/1773 ━━━━━━━━━━━━━━━━━━━━ 16s 9ms/step - accuracy: 0.0000e+00 - auc: 0.5000 - logcosh: 76.1852 - loss: 47273072.0000 - mean_absolute_error: 76.8745 - mean_squared_error: 9149.0244 - r2_score: -1.6226 - val_accuracy: 0.0000e+00 - val_auc: 0.5000 - val_logcosh: 90.2656 - val_loss: 44229596.0000 - val_mean_absolute_error: 90.9541 - val_mean_squared_error: 13178.7734 - val_r2_score: -1.5360
# Epoch 15/50
# 1773/1773 ━━━━━━━━━━━━━━━━━━━━ 16s 9ms/step - accuracy: 0.0000e+00 - auc: 0.4679 - logcosh: 74.8084 - loss: 31141726.0000 - mean_absolute_error: 75.4966 - mean_squared_error: 8800.9004 - r2_score: -1.6395 - val_accuracy: 0.0000e+00 - val_auc: 0.5000 - val_logcosh: 89.7181 - val_loss: 41991348.0000 - val_mean_absolute_error: 90.4078 - val_mean_squared_error: 13058.6055 - val_r2_score: -1.5129
# Epoch 16/50
# 1773/1773 ━━━━━━━━━━━━━━━━━━━━ 16s 9ms/step - accuracy: 0.0000e+00 - auc: 0.4986 - logcosh: 74.5311 - loss: 25859796.0000 - mean_absolute_error: 75.2196 - mean_squared_error: 8825.2686 - r2_score: -1.5655 - val_accuracy: 0.0000e+00 - val_auc: 0.5000 - val_logcosh: 89.1837 - val_loss: 39897752.0000 - val_mean_absolute_error: 89.8729 - val_mean_squared_error: 12941.1436 - val_r2_score: -1.4903
# Epoch 17/50
# 1773/1773 ━━━━━━━━━━━━━━━━━━━━ 16s 9ms/step - accuracy: 0.0000e+00 - auc: 0.4955 - logcosh: 73.9702 - loss: 31948058.0000 - mean_absolute_error: 74.6587 - mean_squared_error: 8729.6699 - r2_score: -1.5391 - val_accuracy: 0.0000e+00 - val_auc: 0.5000 - val_logcosh: 88.6445 - val_loss: 37870696.0000 - val_mean_absolute_error: 89.3327 - val_mean_squared_error: 12822.2930 - val_r2_score: -1.4674
# Epoch 18/50
# 1773/1773 ━━━━━━━━━━━━━━━━━━━━ 16s 9ms/step - accuracy: 0.0000e+00 - auc: 0.4890 - logcosh: 73.2675 - loss: 25140440.0000 - mean_absolute_error: 73.9560 - mean_squared_error: 8570.5938 - r2_score: -1.5085 - val_accuracy: 0.0000e+00 - val_auc: 0.5000 - val_logcosh: 88.1092 - val_loss: 35945424.0000 - val_mean_absolute_error: 88.7988 - val_mean_squared_error: 12704.2959 - val_r2_score: -1.4447
# Epoch 19/50
# 1773/1773 ━━━━━━━━━━━━━━━━━━━━ 16s 9ms/step - accuracy: 0.0000e+00 - auc: 0.4907 - logcosh: 73.6306 - loss: 21344214.0000 - mean_absolute_error: 74.3194 - mean_squared_error: 8592.8330 - r2_score: -1.5344 - val_accuracy: 0.0000e+00 - val_auc: 0.5000 - val_logcosh: 87.5555 - val_loss: 34037644.0000 - val_mean_absolute_error: 88.2441 - val_mean_squared_error: 12581.9668 - val_r2_score: -1.4212
# Epoch 20/50
# 1773/1773 ━━━━━━━━━━━━━━━━━━━━ 16s 9ms/step - accuracy: 0.0000e+00 - auc: 0.4955 - logcosh: 72.5295 - loss: 25440340.0000 - mean_absolute_error: 73.2174 - mean_squared_error: 8481.0654 - r2_score: -1.4393 - val_accuracy: 0.0000e+00 - val_auc: 0.5000 - val_logcosh: 87.0331 - val_loss: 32315266.0000 - val_mean_absolute_error: 87.7206 - val_mean_squared_error: 12466.3711 - val_r2_score: -1.3990
# Epoch 21/50
# 1773/1773 ━━━━━━━━━━━━━━━━━━━━ 17s 9ms/step - accuracy: 0.0000e+00 - auc: 0.4952 - logcosh: 71.5637 - loss: 25524724.0000 - mean_absolute_error: 72.2525 - mean_squared_error: 8302.0625 - r2_score: -1.4067 - val_accuracy: 0.0000e+00 - val_auc: 0.5000 - val_logcosh: 86.5075 - val_loss: 30657036.0000 - val_mean_absolute_error: 87.1970 - val_mean_squared_error: 12350.0527 - val_r2_score: -1.3766
# Epoch 22/50
# 1773/1773 ━━━━━━━━━━━━━━━━━━━━ 16s 9ms/step - accuracy: 0.0000e+00 - auc: 0.4893 - logcosh: 71.4336 - loss: 25431572.0000 - mean_absolute_error: 72.1217 - mean_squared_error: 8282.3555 - r2_score: -1.3735 - val_accuracy: 0.0000e+00 - val_auc: 0.5000 - val_logcosh: 85.9971 - val_loss: 29112418.0000 - val_mean_absolute_error: 86.6863 - val_mean_squared_error: 12236.8203 - val_r2_score: -1.3548
# Epoch 23/50
# 1773/1773 ━━━━━━━━━━━━━━━━━━━━ 16s 9ms/step - accuracy: 0.0000e+00 - auc: 0.4994 - logcosh: 70.6644 - loss: 26454692.0000 - mean_absolute_error: 71.3522 - mean_squared_error: 8108.0840 - r2_score: -1.3680 - val_accuracy: 0.0000e+00 - val_auc: 0.5000 - val_logcosh: 85.4961 - val_loss: 27657852.0000 - val_mean_absolute_error: 86.1840 - val_mean_squared_error: 12125.4580 - val_r2_score: -1.3334
# Epoch 24/50
# 1773/1773 ━━━━━━━━━━━━━━━━━━━━ 16s 9ms/step - accuracy: 0.0000e+00 - auc: 0.4986 - logcosh: 70.4510 - loss: 16506552.0000 - mean_absolute_error: 71.1396 - mean_squared_error: 8055.4272 - r2_score: -1.3490 - val_accuracy: 0.0000e+00 - val_auc: 0.5000 - val_logcosh: 84.9638 - val_loss: 26179232.0000 - val_mean_absolute_error: 85.6527 - val_mean_squared_error: 12007.0557 - val_r2_score: -1.3106
# Epoch 25/50
# 1773/1773 ━━━━━━━━━━━━━━━━━━━━ 16s 9ms/step - accuracy: 0.0000e+00 - auc: 0.4961 - logcosh: 69.4895 - loss: 17982704.0000 - mean_absolute_error: 70.1783 - mean_squared_error: 7862.9048 - r2_score: -1.3206 - val_accuracy: 0.0000e+00 - val_auc: 0.5000 - val_logcosh: 84.4342 - val_loss: 24772498.0000 - val_mean_absolute_error: 85.1235 - val_mean_squared_error: 11889.0566 - val_r2_score: -1.2879
# Epoch 26/50
# 1773/1773 ━━━━━━━━━━━━━━━━━━━━ 16s 9ms/step - accuracy: 0.0000e+00 - auc: 0.4899 - logcosh: 69.7405 - loss: 21911978.0000 - mean_absolute_error: 70.4298 - mean_squared_error: 7932.3994 - r2_score: -1.2894 - val_accuracy: 0.0000e+00 - val_auc: 0.5000 - val_logcosh: 83.9728 - val_loss: 23596224.0000 - val_mean_absolute_error: 84.6606 - val_mean_squared_error: 11785.9834 - val_r2_score: -1.2680
# Epoch 27/50
# 1773/1773 ━━━━━━━━━━━━━━━━━━━━ 18s 10ms/step - accuracy: 0.0000e+00 - auc: 0.4994 - logcosh: 69.2159 - loss: 24671188.0000 - mean_absolute_error: 69.9042 - mean_squared_error: 7858.9429 - r2_score: -1.2580 - val_accuracy: 0.0000e+00 - val_auc: 0.5000 - val_logcosh: 83.4870 - val_loss: 22407838.0000 - val_mean_absolute_error: 84.1758 - val_mean_squared_error: 11677.3672 - val_r2_score: -1.2471
# Epoch 28/50
# 1773/1773 ━━━━━━━━━━━━━━━━━━━━ 16s 9ms/step - accuracy: 0.0000e+00 - auc: 0.4992 - logcosh: 68.4876 - loss: 12794676.0000 - mean_absolute_error: 69.1746 - mean_squared_error: 7683.9307 - r2_score: -1.2426 - val_accuracy: 0.0000e+00 - val_auc: 0.5000 - val_logcosh: 82.9715 - val_loss: 21199490.0000 - val_mean_absolute_error: 83.6600 - val_mean_squared_error: 11561.8594 - val_r2_score: -1.2249
# Epoch 29/50
# 1773/1773 ━━━━━━━━━━━━━━━━━━━━ 16s 9ms/step - accuracy: 0.0000e+00 - auc: 0.4989 - logcosh: 67.2816 - loss: 13126579.0000 - mean_absolute_error: 67.9696 - mean_squared_error: 7473.6743 - r2_score: -1.1907 - val_accuracy: 0.0000e+00 - val_auc: 0.5000 - val_logcosh: 82.5072 - val_loss: 20158100.0000 - val_mean_absolute_error: 83.1956 - val_mean_squared_error: 11457.8076 - val_r2_score: -1.2049
# Epoch 30/50
# 1773/1773 ━━━━━━━━━━━━━━━━━━━━ 16s 9ms/step - accuracy: 0.0000e+00 - auc: 0.4856 - logcosh: 67.5253 - loss: 13198618.0000 - mean_absolute_error: 68.2141 - mean_squared_error: 7552.3511 - r2_score: -1.1725 - val_accuracy: 0.0000e+00 - val_auc: 0.5000 - val_logcosh: 82.0168 - val_loss: 19101098.0000 - val_mean_absolute_error: 82.7054 - val_mean_squared_error: 11347.4834 - val_r2_score: -1.1836
# Epoch 31/50
# 1773/1773 ━━━━━━━━━━━━━━━━━━━━ 16s 9ms/step - accuracy: 0.0000e+00 - auc: 0.4837 - logcosh: 66.4450 - loss: 12147394.0000 - mean_absolute_error: 67.1322 - mean_squared_error: 7384.5249 - r2_score: -1.1158 - val_accuracy: 0.0000e+00 - val_auc: 0.5000 - val_logcosh: 81.5139 - val_loss: 18064864.0000 - val_mean_absolute_error: 82.2029 - val_mean_squared_error: 11234.2783 - val_r2_score: -1.1619
# Epoch 32/50
# 1773/1773 ━━━━━━━━━━━━━━━━━━━━ 16s 9ms/step - accuracy: 0.0000e+00 - auc: 0.4975 - logcosh: 66.3552 - loss: 11557460.0000 - mean_absolute_error: 67.0434 - mean_squared_error: 7292.3042 - r2_score: -1.1125 - val_accuracy: 0.0000e+00 - val_auc: 0.5000 - val_logcosh: 81.0614 - val_loss: 17171420.0000 - val_mean_absolute_error: 81.7502 - val_mean_squared_error: 11132.2402 - val_r2_score: -1.1422
# Epoch 33/50
# 1773/1773 ━━━━━━━━━━━━━━━━━━━━ 16s 9ms/step - accuracy: 0.0000e+00 - auc: 0.4946 - logcosh: 66.5652 - loss: 13484520.0000 - mean_absolute_error: 67.2545 - mean_squared_error: 7312.7144 - r2_score: -1.1352 - val_accuracy: 0.0000e+00 - val_auc: 0.5000 - val_logcosh: 80.6130 - val_loss: 16320777.0000 - val_mean_absolute_error: 81.3020 - val_mean_squared_error: 11030.9023 - val_r2_score: -1.1227
# Epoch 34/50
# 1773/1773 ━━━━━━━━━━━━━━━━━━━━ 16s 9ms/step - accuracy: 0.0000e+00 - auc: 0.4972 - logcosh: 65.6668 - loss: 10748183.0000 - mean_absolute_error: 66.3543 - mean_squared_error: 7184.2358 - r2_score: -1.0875 - val_accuracy: 0.0000e+00 - val_auc: 0.5000 - val_logcosh: 80.1524 - val_loss: 15482313.0000 - val_mean_absolute_error: 80.8416 - val_mean_squared_error: 10926.6309 - val_r2_score: -1.1027
# Epoch 35/50
# 1773/1773 ━━━━━━━━━━━━━━━━━━━━ 16s 9ms/step - accuracy: 0.0000e+00 - auc: 0.4961 - logcosh: 65.3570 - loss: 9363345.0000 - mean_absolute_error: 66.0457 - mean_squared_error: 7119.0249 - r2_score: -1.0597 - val_accuracy: 0.0000e+00 - val_auc: 0.5000 - val_logcosh: 79.6849 - val_loss: 14667408.0000 - val_mean_absolute_error: 80.3738 - val_mean_squared_error: 10820.7041 - val_r2_score: -1.0823
# Epoch 36/50
# 1773/1773 ━━━━━━━━━━━━━━━━━━━━ 18s 10ms/step - accuracy: 0.0000e+00 - auc: 0.4983 - logcosh: 65.1562 - loss: 14540357.0000 - mean_absolute_error: 65.8445 - mean_squared_error: 7080.6147 - r2_score: -1.0336 - val_accuracy: 0.0000e+00 - val_auc: 0.5000 - val_logcosh: 79.2866 - val_loss: 14001257.0000 - val_mean_absolute_error: 79.9758 - val_mean_squared_error: 10730.4385 - val_r2_score: -1.0649
# Epoch 37/50
# 1773/1773 ━━━━━━━━━━━━━━━━━━━━ 16s 9ms/step - accuracy: 0.0000e+00 - auc: 0.4955 - logcosh: 64.9204 - loss: 10854708.0000 - mean_absolute_error: 65.6091 - mean_squared_error: 7013.0659 - r2_score: -1.0260 - val_accuracy: 0.0000e+00 - val_auc: 0.5000 - val_logcosh: 78.7952 - val_loss: 13211634.0000 - val_mean_absolute_error: 79.4848 - val_mean_squared_error: 10618.7393 - val_r2_score: -1.0434
# Epoch 38/50
# 1773/1773 ━━━━━━━━━━━━━━━━━━━━ 16s 9ms/step - accuracy: 0.0000e+00 - auc: 0.4946 - logcosh: 63.3489 - loss: 8451015.0000 - mean_absolute_error: 64.0368 - mean_squared_error: 6801.3823 - r2_score: -0.9579 - val_accuracy: 0.0000e+00 - val_auc: 0.5000 - val_logcosh: 78.3448 - val_loss: 12519246.0000 - val_mean_absolute_error: 79.0337 - val_mean_squared_error: 10516.1689 - val_r2_score: -1.0237
# Epoch 39/50
# 1773/1773 ━━━━━━━━━━━━━━━━━━━━ 16s 9ms/step - accuracy: 0.0000e+00 - auc: 0.4955 - logcosh: 63.1510 - loss: 9866447.0000 - mean_absolute_error: 63.8398 - mean_squared_error: 6704.5693 - r2_score: -0.9699 - val_accuracy: 0.0000e+00 - val_auc: 0.5000 - val_logcosh: 77.9084 - val_loss: 11877028.0000 - val_mean_absolute_error: 78.5967 - val_mean_squared_error: 10416.7607 - val_r2_score: -1.0045
# Epoch 40/50
# 1773/1773 ━━━━━━━━━━━━━━━━━━━━ 17s 9ms/step - accuracy: 0.0000e+00 - auc: 0.4868 - logcosh: 62.9421 - loss: 11867759.0000 - mean_absolute_error: 63.6303 - mean_squared_error: 6683.5210 - r2_score: -0.9538 - val_accuracy: 0.0000e+00 - val_auc: 0.5000 - val_logcosh: 77.5058 - val_loss: 11307961.0000 - val_mean_absolute_error: 78.1954 - val_mean_squared_error: 10324.9463 - val_r2_score: -0.9869
# Epoch 41/50
# 1773/1773 ━━━━━━━━━━━━━━━━━━━━ 16s 9ms/step - accuracy: 0.0000e+00 - auc: 0.4994 - logcosh: 62.6847 - loss: 9072416.0000 - mean_absolute_error: 63.3736 - mean_squared_error: 6625.4082 - r2_score: -0.9128 - val_accuracy: 0.0000e+00 - val_auc: 0.5000 - val_logcosh: 77.1134 - val_loss: 10773630.0000 - val_mean_absolute_error: 77.8024 - val_mean_squared_error: 10235.2129 - val_r2_score: -0.9696
# Epoch 42/50
# 1773/1773 ━━━━━━━━━━━━━━━━━━━━ 16s 9ms/step - accuracy: 0.0000e+00 - auc: 0.4876 - logcosh: 63.1510 - loss: 6565856.0000 - mean_absolute_error: 63.8388 - mean_squared_error: 6695.0366 - r2_score: -0.9257 - val_accuracy: 0.0000e+00 - val_auc: 0.5000 - val_logcosh: 76.6531 - val_loss: 10172796.0000 - val_mean_absolute_error: 77.3415 - val_mean_squared_error: 10129.8633 - val_r2_score: -0.9493
# Epoch 43/50
# 1773/1773 ━━━━━━━━━━━━━━━━━━━━ 16s 9ms/step - accuracy: 0.0000e+00 - auc: 0.4989 - logcosh: 62.5574 - loss: 6383277.0000 - mean_absolute_error: 63.2459 - mean_squared_error: 6535.6602 - r2_score: -0.8996 - val_accuracy: 0.0000e+00 - val_auc: 0.5000 - val_logcosh: 76.2656 - val_loss: 9687213.0000 - val_mean_absolute_error: 76.9550 - val_mean_squared_error: 10040.9482 - val_r2_score: -0.9322
# Epoch 44/50
# 1773/1773 ━━━━━━━━━━━━━━━━━━━━ 16s 9ms/step - accuracy: 0.0000e+00 - auc: 0.4806 - logcosh: 61.7131 - loss: 8965893.0000 - mean_absolute_error: 62.4013 - mean_squared_error: 6463.5840 - r2_score: -0.8620 - val_accuracy: 0.0000e+00 - val_auc: 0.5000 - val_logcosh: 75.8733 - val_loss: 9214463.0000 - val_mean_absolute_error: 76.5622 - val_mean_squared_error: 9950.8330 - val_r2_score: -0.9149
# Epoch 45/50
# 1773/1773 ━━━━━━━━━━━━━━━━━━━━ 16s 9ms/step - accuracy: 0.0000e+00 - auc: 0.4946 - logcosh: 61.1090 - loss: 7900910.0000 - mean_absolute_error: 61.7961 - mean_squared_error: 6297.4551 - r2_score: -0.8489 - val_accuracy: 0.0000e+00 - val_auc: 0.5000 - val_logcosh: 75.5179 - val_loss: 8802479.0000 - val_mean_absolute_error: 76.2067 - val_mean_squared_error: 9869.1846 - val_r2_score: -0.8992
# Epoch 46/50
# 1773/1773 ━━━━━━━━━━━━━━━━━━━━ 16s 9ms/step - accuracy: 0.0000e+00 - auc: 0.4822 - logcosh: 61.4138 - loss: 9536050.0000 - mean_absolute_error: 62.1016 - mean_squared_error: 6339.9951 - r2_score: -0.8426 - val_accuracy: 0.0000e+00 - val_auc: 0.5000 - val_logcosh: 75.1367 - val_loss: 8375901.0000 - val_mean_absolute_error: 75.8262 - val_mean_squared_error: 9781.3174 - val_r2_score: -0.8823
# Epoch 47/50
# 1773/1773 ━━━━━━━━━━━━━━━━━━━━ 16s 9ms/step - accuracy: 0.0000e+00 - auc: 0.4980 - logcosh: 60.7886 - loss: 5587422.5000 - mean_absolute_error: 61.4779 - mean_squared_error: 6220.2729 - r2_score: -0.8065 - val_accuracy: 0.0000e+00 - val_auc: 0.5000 - val_logcosh: 74.7433 - val_loss: 7953179.5000 - val_mean_absolute_error: 75.4322 - val_mean_squared_error: 9690.5996 - val_r2_score: -0.8648
# Epoch 48/50
# 1773/1773 ━━━━━━━━━━━━━━━━━━━━ 16s 9ms/step - accuracy: 0.0000e+00 - auc: 0.4989 - logcosh: 60.5468 - loss: 7748237.5000 - mean_absolute_error: 61.2347 - mean_squared_error: 6213.9937 - r2_score: -0.7820 - val_accuracy: 0.0000e+00 - val_auc: 0.5000 - val_logcosh: 74.3768 - val_loss: 7574189.0000 - val_mean_absolute_error: 75.0659 - val_mean_squared_error: 9605.9014 - val_r2_score: -0.8485
# Epoch 49/50
# 1773/1773 ━━━━━━━━━━━━━━━━━━━━ 16s 9ms/step - accuracy: 0.0000e+00 - auc: 0.4966 - logcosh: 60.3406 - loss: 8564356.0000 - mean_absolute_error: 61.0282 - mean_squared_error: 6162.5347 - r2_score: -0.7772 - val_accuracy: 0.0000e+00 - val_auc: 0.5000 - val_logcosh: 73.9855 - val_loss: 7184826.5000 - val_mean_absolute_error: 74.6748 - val_mean_squared_error: 9515.2568 - val_r2_score: -0.8311
# Epoch 50/50
# 1773/1773 ━━━━━━━━━━━━━━━━━━━━ 16s 9ms/step - accuracy: 0.0000e+00 - auc: 0.4907 - logcosh: 59.8021 - loss: 6073945.0000 - mean_absolute_error: 60.4906 - mean_squared_error: 6087.4844 - r2_score: -0.7426 - val_accuracy: 0.0000e+00 - val_auc: 0.5000 - val_logcosh: 73.6055 - val_loss: 6821937.5000 - val_mean_absolute_error: 74.2943 - val_mean_squared_error: 9427.1562 - val_r2_score: -0.8141
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 💾 Model saved as 'base_rul_LSTM_0.h5

# %% [markdown]
# ### We can see from the above loss curve , that the base model is overfitting .

# %%
def base_lstm_model_01(input_shape):
    model = Sequential()
    model.add(LSTM(64, return_sequences=True, input_shape=input_shape))
    model.add(Dropout(0.3))
    model.add(LSTM(32))

    model.add(Dense(1))

    model.compile(
        optimizer=Adam(learning_rate=0.000125),
        loss=asymmetric_loss,
        metrics=[
            tf.keras.metrics.MeanAbsoluteError(),
            tf.keras.metrics.LogCoshError(),
            tf.keras.metrics.MeanSquaredError(),
            tf.keras.metrics.R2Score(),
        ],
    )
    return model

# %%
def main():

    print("📥 Loading data...")
    df = load_and_preprocess_data(DATA_PATH)

    feature_columns = OP_COLS + SENSOR_COLS
    df, scaler = normalize(df, feature_columns)

    print("🔁 Creating sequences...")
    X, y = create_sequences(df, SEQUENCE_LENGTH, feature_columns)

    print(f"✅ Input shape to LSTM: {X.shape}")  # Should be (samples, 30, features)
    print(f"✅ Target shape: {y.shape}")  # Should be (samples, 1)

    model = base_lstm_model_01(input_shape=(SEQUENCE_LENGTH, len(feature_columns)))
    model.summary()

    print("🚀 Training LSTM model_01 with asymmetric PHM08 loss...")
    history = train_model(model, X, y)

    plot_loss(history)

    model.save("base_rul_LSTM_01.h5")
    print("💾 Model saved as 'base_rul_LSTM_01.h5")


if __name__ == "__main__":
    main()
# Out:
# 📥 Loading data...
# 🔁 Creating sequences...
# ✅ Input shape to LSTM: (17731, 30, 24)
# ✅ Target shape: (17731, 1)
# d:\turbofan_RUL\Turbofan-Engine-Remaining_Useful_Life\tf_rul\lib\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_2 (LSTM)                   │ (None, 30, 64)         │        22,784 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 30, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_3 (LSTM)                   │ (None, 32)             │        12,416 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 35,233 (137.63 KB)
#  Trainable params: 35,233 (137.63 KB)
#  Non-trainable params: 0 (0.00 B)
# 🚀 Training LSTM model_01 with asymmetric PHM08 loss...
# Epoch 1/50
# 1773/1773 ━━━━━━━━━━━━━━━━━━━━ 20s 10ms/step - logcosh: 87.9959 - loss: 95143944.0000 - mean_absolute_error: 88.6850 - mean_squared_error: 11342.2383 - r2_score: -2.2566 - val_logcosh: 98.8159 - val_loss: 94464960.0000 - val_mean_absolute_error: 99.5037 - val_mean_squared_error: 15038.4756 - val_r2_score: -1.8939
# Epoch 2/50
# 1773/1773 ━━━━━━━━━━━━━━━━━━━━ 16s 9ms/step - logcosh: 83.2340 - loss: 82395200.0000 - mean_absolute_error: 83.9220 - mean_squared_error: 10456.6836 - r2_score: -2.0127 - val_logcosh: 97.5506 - val_loss: 84891992.0000 - val_mean_absolute_error: 98.2395 - val_mean_squared_error: 14765.0635 - val_r2_score: -1.8413
# Epoch 3/50
# 1773/1773 ━━━━━━━━━━━━━━━━━━━━ 17s 10ms/step - logcosh: 81.8559 - loss: 47377288.0000 - mean_absolute_error: 82.5443 - mean_squared_error: 10113.4355 - r2_score: -2.0032 - val_logcosh: 96.6172 - val_loss: 78377336.0000 - val_mean_absolute_error: 97.3067 - val_mean_squared_error: 14563.1377 - val_r2_score: -1.8024
# Epoch 4/50
# 1773/1773 ━━━━━━━━━━━━━━━━━━━━ 17s 9ms/step - logcosh: 81.2547 - loss: 107945240.0000 - mean_absolute_error: 81.9432 - mean_squared_error: 10117.1055 - r2_score: -1.8966 - val_logcosh: 95.8926 - val_loss: 73613856.0000 - val_mean_absolute_error: 96.5810 - val_mean_squared_error: 14406.0166 - val_r2_score: -1.7722
# Epoch 5/50
# 1773/1773 ━━━━━━━━━━━━━━━━━━━━ 16s 9ms/step - logcosh: 81.5011 - loss: 51275768.0000 - mean_absolute_error: 82.1900 - mean_squared_error: 10092.7393 - r2_score: -1.9326 - val_logcosh: 95.0878 - val_loss: 68613448.0000 - val_mean_absolute_error: 95.7760 - val_mean_squared_error: 14231.3369 - val_r2_score: -1.7386
# Epoch 6/50
# 1773/1773 ━━━━━━━━━━━━━━━━━━━━ 16s 9ms/step - logcosh: 79.7204 - loss: 56440276.0000 - mean_absolute_error: 80.4082 - mean_squared_error: 9798.0918 - r2_score: -1.8331 - val_logcosh: 94.3912 - val_loss: 64519444.0000 - val_mean_absolute_error: 95.0791 - val_mean_squared_error: 14079.9375 - val_r2_score: -1.7095
# Epoch 7/50
# 1773/1773 ━━━━━━━━━━━━━━━━━━━━ 16s 9ms/step - logcosh: 79.9074 - loss: 50331372.0000 - mean_absolute_error: 80.5957 - mean_squared_error: 9821.0820 - r2_score: -1.8331 - val_logcosh: 93.2996 - val_loss: 58518036.0000 - val_mean_absolute_error: 93.9881 - val_mean_squared_error: 13842.3076 - val_r2_score: -1.6637
# Epoch 8/50
# 1773/1773 ━━━━━━━━━━━━━━━━━━━━ 16s 9ms/step - logcosh: 77.6479 - loss: 31353724.0000 - mean_absolute_error: 78.3364 - mean_squared_error: 9428.1729 - r2_score: -1.7224 - val_logcosh: 92.5486 - val_loss: 54668724.0000 - val_mean_absolute_error: 93.2375 - val_mean_squared_error: 13678.5840 - val_r2_score: -1.6322
# Epoch 9/50
# 1773/1773 ━━━━━━━━━━━━━━━━━━━━ 16s 9ms/step - logcosh: 76.8922 - loss: 33027522.0000 - mean_absolute_error: 77.5805 - mean_squared_error: 9238.8027 - r2_score: -1.7049 - val_logcosh: 91.7841 - val_loss: 50967012.0000 - val_mean_absolute_error: 92.4724 - val_mean_squared_error: 13511.5322 - val_r2_score: -1.6001
# Epoch 10/50
# 1773/1773 ━━━━━━━━━━━━━━━━━━━━ 16s 9ms/step - logcosh: 76.4348 - loss: 35196132.0000 - mean_absolute_error: 77.1231 - mean_squared_error: 9194.2471 - r2_score: -1.6508 - val_logcosh: 91.0690 - val_loss: 47694536.0000 - val_mean_absolute_error: 91.7574 - val_mean_squared_error: 13354.9355 - val_r2_score: -1.5699
# Epoch 11/50
# 1773/1773 ━━━━━━━━━━━━━━━━━━━━ 16s 9ms/step - logcosh: 75.4312 - loss: 36958884.0000 - mean_absolute_error: 76.1184 - mean_squared_error: 8982.8848 - r2_score: -1.6234 - val_logcosh: 90.3579 - val_loss: 44617892.0000 - val_mean_absolute_error: 91.0473 - val_mean_squared_error: 13199.0938 - val_r2_score: -1.5400
# Epoch 12/50
# 1773/1773 ━━━━━━━━━━━━━━━━━━━━ 16s 9ms/step - logcosh: 76.3148 - loss: 33411104.0000 - mean_absolute_error: 77.0035 - mean_squared_error: 9143.1875 - r2_score: -1.6310 - val_logcosh: 89.6823 - val_loss: 41847964.0000 - val_mean_absolute_error: 90.3714 - val_mean_squared_error: 13050.7197 - val_r2_score: -1.5114
# Epoch 13/50
# 1773/1773 ━━━━━━━━━━━━━━━━━━━━ 16s 9ms/step - logcosh: 74.7673 - loss: 36012556.0000 - mean_absolute_error: 75.4556 - mean_squared_error: 8868.2227 - r2_score: -1.5598 - val_logcosh: 88.9892 - val_loss: 39155632.0000 - val_mean_absolute_error: 89.6781 - val_mean_squared_error: 12898.2393 - val_r2_score: -1.4821
# Epoch 14/50
# 1773/1773 ━━━━━━━━━━━━━━━━━━━━ 17s 9ms/step - logcosh: 73.9891 - loss: 33991012.0000 - mean_absolute_error: 74.6779 - mean_squared_error: 8753.2451 - r2_score: -1.5256 - val_logcosh: 88.3243 - val_loss: 36709656.0000 - val_mean_absolute_error: 89.0137 - val_mean_squared_error: 12751.7627 - val_r2_score: -1.4539
# Epoch 15/50
# 1773/1773 ━━━━━━━━━━━━━━━━━━━━ 16s 9ms/step - logcosh: 73.1392 - loss: 31257602.0000 - mean_absolute_error: 73.8278 - mean_squared_error: 8540.1357 - r2_score: -1.4920 - val_logcosh: 87.6649 - val_loss: 34407196.0000 - val_mean_absolute_error: 88.3531 - val_mean_squared_error: 12606.0928 - val_r2_score: -1.4258
# Epoch 16/50
# 1773/1773 ━━━━━━━━━━━━━━━━━━━━ 16s 9ms/step - logcosh: 73.6077 - loss: 32399514.0000 - mean_absolute_error: 74.2968 - mean_squared_error: 8610.3252 - r2_score: -1.5049 - val_logcosh: 87.0022 - val_loss: 32215898.0000 - val_mean_absolute_error: 87.6900 - val_mean_squared_error: 12459.5420 - val_r2_score: -1.3976
# Epoch 17/50
# 1773/1773 ━━━━━━━━━━━━━━━━━━━━ 16s 9ms/step - logcosh: 72.2831 - loss: 17819826.0000 - mean_absolute_error: 72.9711 - mean_squared_error: 8353.3486 - r2_score: -1.4496 - val_logcosh: 86.3318 - val_loss: 30118034.0000 - val_mean_absolute_error: 87.0207 - val_mean_squared_error: 12311.1035 - val_r2_score: -1.3691
# Epoch 18/50
# 1773/1773 ━━━━━━━━━━━━━━━━━━━━ 16s 9ms/step - logcosh: 72.0612 - loss: 21542736.0000 - mean_absolute_error: 72.7497 - mean_squared_error: 8351.2725 - r2_score: -1.4021 - val_logcosh: 85.6983 - val_loss: 28237080.0000 - val_mean_absolute_error: 86.3866 - val_mean_squared_error: 12170.3848 - val_r2_score: -1.3420
# Epoch 19/50
# 1773/1773 ━━━━━━━━━━━━━━━━━━━━ 16s 9ms/step - logcosh: 70.5038 - loss: 18598672.0000 - mean_absolute_error: 71.1928 - mean_squared_error: 8090.7974 - r2_score: -1.3359 - val_logcosh: 85.0267 - val_loss: 26350884.0000 - val_mean_absolute_error: 85.7157 - val_mean_squared_error: 12021.0811 - val_r2_score: -1.3133
# Epoch 20/50
# 1773/1773 ━━━━━━━━━━━━━━━━━━━━ 16s 9ms/step - logcosh: 70.1378 - loss: 20552978.0000 - mean_absolute_error: 70.8264 - mean_squared_error: 7967.1641 - r2_score: -1.3310 - val_logcosh: 84.4139 - val_loss: 24719886.0000 - val_mean_absolute_error: 85.1034 - val_mean_squared_error: 11884.5400 - val_r2_score: -1.2870
# Epoch 21/50
# 1773/1773 ━━━━━━━━━━━━━━━━━━━━ 16s 9ms/step - logcosh: 69.2467 - loss: 16355072.0000 - mean_absolute_error: 69.9357 - mean_squared_error: 7818.4194 - r2_score: -1.2836 - val_logcosh: 83.7762 - val_loss: 23109048.0000 - val_mean_absolute_error: 84.4650 - val_mean_squared_error: 11742.0264 - val_r2_score: -1.2596
# Epoch 22/50
# 1773/1773 ━━━━━━━━━━━━━━━━━━━━ 16s 9ms/step - logcosh: 68.4489 - loss: 18112254.0000 - mean_absolute_error: 69.1377 - mean_squared_error: 7703.7998 - r2_score: -1.2415 - val_logcosh: 83.1445 - val_loss: 21600258.0000 - val_mean_absolute_error: 83.8335 - val_mean_squared_error: 11600.7715 - val_r2_score: -1.2324
# Epoch 23/50
# 1773/1773 ━━━━━━━━━━━━━━━━━━━━ 16s 9ms/step - logcosh: 68.0548 - loss: 18356162.0000 - mean_absolute_error: 68.7436 - mean_squared_error: 7616.7690 - r2_score: -1.2176 - val_logcosh: 82.5346 - val_loss: 20218304.0000 - val_mean_absolute_error: 83.2228 - val_mean_squared_error: 11463.9414 - val_r2_score: -1.2061
# Epoch 24/50
# 1773/1773 ━━━━━━━━━━━━━━━━━━━━ 16s 9ms/step - logcosh: 67.9638 - loss: 16501734.0000 - mean_absolute_error: 68.6526 - mean_squared_error: 7624.8306 - r2_score: -1.1945 - val_logcosh: 81.9588 - val_loss: 18979968.0000 - val_mean_absolute_error: 82.6473 - val_mean_squared_error: 11334.5254 - val_r2_score: -1.1812
# Epoch 25/50
# 1773/1773 ━━━━━━━━━━━━━━━━━━━━ 16s 9ms/step - logcosh: 67.2322 - loss: 13295025.0000 - mean_absolute_error: 67.9204 - mean_squared_error: 7449.1455 - r2_score: -1.1685 - val_logcosh: 81.3314 - val_loss: 17700408.0000 - val_mean_absolute_error: 82.0206 - val_mean_squared_error: 11193.1875 - val_r2_score: -1.1540
# Epoch 26/50
# 1773/1773 ━━━━━━━━━━━━━━━━━━━━ 16s 9ms/step - logcosh: 67.3185 - loss: 8318513.0000 - mean_absolute_error: 68.0071 - mean_squared_error: 7429.1689 - r2_score: -1.1708 - val_logcosh: 80.7055 - val_loss: 16493449.0000 - val_mean_absolute_error: 81.3948 - val_mean_squared_error: 11051.8252 - val_r2_score: -1.1268
# Epoch 27/50
# 1773/1773 ━━━━━━━━━━━━━━━━━━━━ 16s 9ms/step - logcosh: 66.0616 - loss: 12745536.0000 - mean_absolute_error: 66.7491 - mean_squared_error: 7253.0254 - r2_score: -1.0874 - val_logcosh: 80.1560 - val_loss: 15488814.0000 - val_mean_absolute_error: 80.8451 - val_mean_squared_error: 10927.4551 - val_r2_score: -1.1028
# Epoch 28/50
# 1773/1773 ━━━━━━━━━━━━━━━━━━━━ 18s 10ms/step - logcosh: 65.2238 - loss: 10155817.0000 - mean_absolute_error: 65.9122 - mean_squared_error: 7080.0127 - r2_score: -1.0598 - val_logcosh: 79.5826 - val_loss: 14493740.0000 - val_mean_absolute_error: 80.2716 - val_mean_squared_error: 10797.5068 - val_r2_score: -1.0778
# Epoch 29/50
# 1773/1773 ━━━━━━━━━━━━━━━━━━━━ 17s 9ms/step - logcosh: 65.1040 - loss: 10503067.0000 - mean_absolute_error: 65.7926 - mean_squared_error: 7091.7563 - r2_score: -1.0105 - val_logcosh: 79.0373 - val_loss: 13595547.0000 - val_mean_absolute_error: 79.7263 - val_mean_squared_error: 10673.7178 - val_r2_score: -1.0540
# Epoch 30/50
# 1773/1773 ━━━━━━━━━━━━━━━━━━━━ 17s 9ms/step - logcosh: 64.4067 - loss: 10259876.0000 - mean_absolute_error: 65.0951 - mean_squared_error: 6942.4136 - r2_score: -0.9961 - val_logcosh: 78.4805 - val_loss: 12725178.0000 - val_mean_absolute_error: 79.1690 - val_mean_squared_error: 10547.1494 - val_r2_score: -1.0296
# Epoch 31/50
# 1773/1773 ━━━━━━━━━━━━━━━━━━━━ 17s 9ms/step - logcosh: 63.7261 - loss: 7997177.0000 - mean_absolute_error: 64.4141 - mean_squared_error: 6799.1748 - r2_score: -0.9762 - val_logcosh: 77.8905 - val_loss: 11850785.0000 - val_mean_absolute_error: 78.5784 - val_mean_squared_error: 10412.6162 - val_r2_score: -1.0037
# Epoch 32/50
# 1773/1773 ━━━━━━━━━━━━━━━━━━━━ 16s 9ms/step - logcosh: 63.1870 - loss: 7653287.5000 - mean_absolute_error: 63.8748 - mean_squared_error: 6670.4238 - r2_score: -0.9574 - val_logcosh: 77.3784 - val_loss: 11131658.0000 - val_mean_absolute_error: 78.0674 - val_mean_squared_error: 10295.7275 - val_r2_score: -0.9813
# Epoch 33/50
# 1773/1773 ━━━━━━━━━━━━━━━━━━━━ 16s 9ms/step - logcosh: 62.4879 - loss: 6726112.0000 - mean_absolute_error: 63.1758 - mean_squared_error: 6561.0542 - r2_score: -0.9126 - val_logcosh: 76.8328 - val_loss: 10403652.0000 - val_mean_absolute_error: 77.5220 - val_mean_squared_error: 10170.9268 - val_r2_score: -0.9572
# Epoch 34/50
# 1773/1773 ━━━━━━━━━━━━━━━━━━━━ 16s 9ms/step - logcosh: 61.8651 - loss: 7108867.5000 - mean_absolute_error: 62.5536 - mean_squared_error: 6427.2949 - r2_score: -0.8942 - val_logcosh: 76.3191 - val_loss: 9753208.0000 - val_mean_absolute_error: 77.0086 - val_mean_squared_error: 10053.2451 - val_r2_score: -0.9346
# Epoch 35/50
# 1773/1773 ━━━━━━━━━━━━━━━━━━━━ 16s 9ms/step - logcosh: 61.3971 - loss: 7750793.0000 - mean_absolute_error: 62.0857 - mean_squared_error: 6344.5024 - r2_score: -0.8616 - val_logcosh: 75.7785 - val_loss: 9103123.0000 - val_mean_absolute_error: 76.4679 - val_mean_squared_error: 9929.0635 - val_r2_score: -0.9107
# Epoch 36/50
# 1773/1773 ━━━━━━━━━━━━━━━━━━━━ 16s 9ms/step - logcosh: 60.8123 - loss: 5673664.0000 - mean_absolute_error: 61.5012 - mean_squared_error: 6239.8096 - r2_score: -0.8264 - val_logcosh: 75.2714 - val_loss: 8524529.0000 - val_mean_absolute_error: 75.9604 - val_mean_squared_error: 9812.3359 - val_r2_score: -0.8882
# Epoch 37/50
# 1773/1773 ━━━━━━━━━━━━━━━━━━━━ 16s 9ms/step - logcosh: 61.1132 - loss: 8085297.0000 - mean_absolute_error: 61.8017 - mean_squared_error: 6279.9473 - r2_score: -0.8226 - val_logcosh: 74.8137 - val_loss: 8027587.0000 - val_mean_absolute_error: 75.5021 - val_mean_squared_error: 9706.8428 - val_r2_score: -0.8679
# Epoch 38/50
# 1773/1773 ━━━━━━━━━━━━━━━━━━━━ 16s 9ms/step - logcosh: 61.2325 - loss: 4357816.5000 - mean_absolute_error: 61.9209 - mean_squared_error: 6322.8237 - r2_score: -0.8031 - val_logcosh: 74.2603 - val_loss: 7456552.0000 - val_mean_absolute_error: 74.9485 - val_mean_squared_error: 9578.9199 - val_r2_score: -0.8433
# Epoch 39/50
# 1773/1773 ━━━━━━━━━━━━━━━━━━━━ 16s 9ms/step - logcosh: 59.8850 - loss: 6537666.5000 - mean_absolute_error: 60.5738 - mean_squared_error: 6069.2466 - r2_score: -0.7485 - val_logcosh: 73.7922 - val_loss: 6998653.5000 - val_mean_absolute_error: 74.4813 - val_mean_squared_error: 9470.5186 - val_r2_score: -0.8225
# Epoch 40/50
# 1773/1773 ━━━━━━━━━━━━━━━━━━━━ 16s 9ms/step - logcosh: 58.6796 - loss: 5299742.0000 - mean_absolute_error: 59.3674 - mean_squared_error: 5861.1729 - r2_score: -0.7210 - val_logcosh: 73.3223 - val_loss: 6560933.5000 - val_mean_absolute_error: 74.0117 - val_mean_squared_error: 9361.4414 - val_r2_score: -0.8015
# Epoch 41/50
# 1773/1773 ━━━━━━━━━━━━━━━━━━━━ 16s 9ms/step - logcosh: 58.7449 - loss: 3220437.0000 - mean_absolute_error: 59.4334 - mean_squared_error: 5812.2944 - r2_score: -0.7189 - val_logcosh: 72.8349 - val_loss: 6128858.0000 - val_mean_absolute_error: 73.5243 - val_mean_squared_error: 9247.9189 - val_r2_score: -0.7796
# Epoch 42/50
# 1773/1773 ━━━━━━━━━━━━━━━━━━━━ 16s 9ms/step - logcosh: 58.1730 - loss: 3829499.2500 - mean_absolute_error: 58.8613 - mean_squared_error: 5703.0059 - r2_score: -0.6915 - val_logcosh: 72.3819 - val_loss: 5747199.5000 - val_mean_absolute_error: 73.0712 - val_mean_squared_error: 9142.2168 - val_r2_score: -0.7593
# Epoch 43/50
# 1773/1773 ━━━━━━━━━━━━━━━━━━━━ 17s 10ms/step - logcosh: 58.1916 - loss: 3237863.0000 - mean_absolute_error: 58.8810 - mean_squared_error: 5744.6152 - r2_score: -0.6620 - val_logcosh: 71.8985 - val_loss: 5360178.5000 - val_mean_absolute_error: 72.5877 - val_mean_squared_error: 9029.1777 - val_r2_score: -0.7375
# Epoch 44/50
# 1773/1773 ━━━━━━━━━━━━━━━━━━━━ 17s 9ms/step - logcosh: 57.6604 - loss: 4581788.5000 - mean_absolute_error: 58.3497 - mean_squared_error: 5634.1816 - r2_score: -0.6367 - val_logcosh: 71.4623 - val_loss: 5027758.0000 - val_mean_absolute_error: 72.1504 - val_mean_squared_error: 8926.8164 - val_r2_score: -0.7178
# Epoch 45/50
# 1773/1773 ━━━━━━━━━━━━━━━━━━━━ 16s 9ms/step - logcosh: 57.1757 - loss: 3667708.5000 - mean_absolute_error: 57.8642 - mean_squared_error: 5561.6045 - r2_score: -0.6204 - val_logcosh: 71.0145 - val_loss: 4703255.0000 - val_mean_absolute_error: 71.7027 - val_mean_squared_error: 8821.6201 - val_r2_score: -0.6976
# Epoch 46/50
# 1773/1773 ━━━━━━━━━━━━━━━━━━━━ 16s 9ms/step - logcosh: 57.5834 - loss: 4408816.0000 - mean_absolute_error: 58.2718 - mean_squared_error: 5676.5024 - r2_score: -0.5951 - val_logcosh: 70.5971 - val_loss: 4414704.0000 - val_mean_absolute_error: 71.2862 - val_mean_squared_error: 8723.1885 - val_r2_score: -0.6786
# Epoch 47/50
# 1773/1773 ━━━━━━━━━━━━━━━━━━━━ 16s 9ms/step - logcosh: 55.9092 - loss: 2873660.7500 - mean_absolute_error: 56.5967 - mean_squared_error: 5308.8052 - r2_score: -0.5783 - val_logcosh: 70.1601 - val_loss: 4126966.5000 - val_mean_absolute_error: 70.8495 - val_mean_squared_error: 8619.8877 - val_r2_score: -0.6588
# Epoch 48/50
# 1773/1773 ━━━━━━━━━━━━━━━━━━━━ 16s 9ms/step - logcosh: 56.4391 - loss: 2625082.5000 - mean_absolute_error: 57.1273 - mean_squared_error: 5380.9854 - r2_score: -0.5562 - val_logcosh: 69.7248 - val_loss: 3853779.5000 - val_mean_absolute_error: 70.4141 - val_mean_squared_error: 8516.4941 - val_r2_score: -0.6389
# Epoch 49/50
# 1773/1773 ━━━━━━━━━━━━━━━━━━━━ 16s 9ms/step - logcosh: 55.5932 - loss: 2613273.7500 - mean_absolute_error: 56.2816 - mean_squared_error: 5251.2134 - r2_score: -0.5269 - val_logcosh: 69.2922 - val_loss: 3596129.2500 - val_mean_absolute_error: 69.9817 - val_mean_squared_error: 8413.6377 - val_r2_score: -0.6191
# Epoch 50/50
# 1773/1773 ━━━━━━━━━━━━━━━━━━━━ 16s 9ms/step - logcosh: 54.8305 - loss: 2928924.7500 - mean_absolute_error: 55.5186 - mean_squared_error: 5137.8628 - r2_score: -0.4862 - val_logcosh: 68.9079 - val_loss: 3377655.5000 - val_mean_absolute_error: 69.5972 - val_mean_squared_error: 8321.8770 - val_r2_score: -0.6014
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 💾 Model saved as 'base_rul_LSTM_01.h5

# %% [markdown]
# ### Our Base LSTM Model Architecture :
#
#
# ### def base_lstm_model(input_shape):
#     model = Sequential()
#     model.add(LSTM(64, return_sequences=True, input_shape=input_shape))
#     model.add(Dropout(0.3))
#     model.add(LSTM(32))
#     model.add(Dropout(0.3))
#     model.add(Dense(1))
#
#     model.compile(
#         optimizer=Adam(learning_rate=0.00012),
#         loss=asymmetric_loss,
#         metrics=[
#             tf.keras.metrics.MeanAbsoluteError(),
#             tf.keras.metrics.AUC(),
#             tf.keras.metrics.Accuracy(),
#             tf.keras.metrics.LogCoshError(),
#             tf.keras.metrics.MeanSquaredError(),
#             tf.keras.metrics.R2Score(),
#         ],
#     )
#     return model

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout


def base_lstm_model_01(input_shape):
    model = Sequential(
        [
            LSTM(64, return_sequences=True, input_shape=input_shape),
            Dropout(0.2),
            LSTM(32),
            Dense(1),
        ]
    )
    return model


def base_lstm_model_02(input_shape):
    model = Sequential(
        [
            LSTM(128, return_sequences=True, input_shape=input_shape),
            Dropout(0.3),
            LSTM(64),
            Dense(1),
        ]
    )
    return model

# %%
import matplotlib.pyplot as plt

import mlflow


def log_learning_curve(history, name="loss_curve"):
    plt.figure()
    plt.plot(history.history["loss"], label="Train Loss")
    plt.plot(history.history["val_loss"], label="Val Loss")
    plt.legend()
    plt.title("Loss Curve")
    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    plt.grid(True)
    plt.savefig("loss_curve.png")
    mlflow.log_artifact("loss_curve.png", artifact_path="plots")

# %%
import mlflow.keras
from tensorflow.keras.callbacks import LambdaCallback


log_metrics_callback = LambdaCallback(
    on_epoch_end=lambda epoch, logs: [
        mlflow.log_metric("loss", logs["loss"], step=epoch),
        mlflow.log_metric("mae", logs["mae"], step=epoch),
        mlflow.log_metric("val_loss", logs["val_loss"], step=epoch),
        mlflow.log_metric("val_mae", logs["val_mae"], step=epoch),
    ]
)

# %%
import os
from tensorflow.keras.callbacks import TensorBoard, ModelCheckpoint


def get_callbacks(model_name):
    tensorboard_cb = TensorBoard(log_dir=f"logs/{model_name}")
    checkpoint_cb = ModelCheckpoint(
        f"saved_models/{model_name}.h5", save_best_only=True
    )
    return [tensorboard_cb, checkpoint_cb]

# %%
import mlflow
import mlflow.tensorflow
import numpy as np
import datetime
from utils import get_callbacks
from utils import *
from tensorflow.keras.optimizers import Adam


def train_model(model, X_train, y_train, epochs=50, batch_size=8, lr=0.000125):

    with mlflow.start_run(run_name=f"model_{model}"):
        mlflow.tensorflow.autolog()

        model.compile(optimizer=Adam(lr), loss="mse", metrics=["mae"])
        # define callbacks within the loop :
        callbacks = get_callbacks(model) + [log_metrics_callback]

        history = model.fit(
            X_train,
            y_train,
            validation_split=0.2,
            epochs=epochs,
            batch_size=batch_size,
            verbose=1,
        )

        # Logging parameters

        mlflow.log_param("model_name", model)
        mlflow.log_param("learning_rate", lr)
        mlflow.log_param("epochs", epochs)
        mlflow.keras.log_model(model, f"{model}_model")

    return model, history

# %%
def main():

    print("📥 Loading data...")
    df = load_and_preprocess_data(DATA_PATH)

    feature_columns = OP_COLS + SENSOR_COLS
    df, scaler = normalize(df, feature_columns)

    print("🔁 Creating sequences...")
    X, y = create_sequences(df, SEQUENCE_LENGTH, feature_columns)

    print(f"✅ Input shape to LSTM: {X.shape}")  # Should be (samples, 30, features)
    print(f"✅ Target shape: {y.shape}")  # Should be (samples, 1)

    model = base_lstm_model_01(input_shape=(SEQUENCE_LENGTH, len(feature_columns)))
    model.summary()

    print("🚀 Training LSTM model_01 with asymmetric PHM08 loss...")
    history = train_model(model, X, y)

    plot_loss(history)

    model.save("expr_LSTM_023y.h5")
    print("💾 Model saved as 'expr_LSTM_023y.h5")


if __name__ == "__main__":
    main()
# Out:
# 📥 Loading data...
# 🔁 Creating sequences...
# ✅ Input shape to LSTM: (17731, 30, 24)
# ✅ Target shape: (17731, 1)
# d:\turbofan_RUL\Turbofan-Engine-Remaining_Useful_Life\tf_rul\lib\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_2 (LSTM)                   │ (None, 30, 64)         │        22,784 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 30, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_3 (LSTM)                   │ (None, 32)             │        12,416 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 35,233 (137.63 KB)
#  Trainable params: 35,233 (137.63 KB)
#  Non-trainable params: 0 (0.00 B)
# 🚀 Training LSTM model_01 with asymmetric PHM08 loss...
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Epoch 1/50
# 1769/1773 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 10398.3955 - mae: 83.4525
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 1773/1773 ━━━━━━━━━━━━━━━━━━━━ 19s 10ms/step - loss: 10396.7949 - mae: 83.4447 - val_loss: 13411.1670 - val_mae: 92.0147
# Epoch 2/50
# 1773/1773 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 8914.9082 - mae: 75.8161
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 1773/1773 ━━━━━━━━━━━━━━━━━━━━ 16s 9ms/step - loss: 8914.7637 - mae: 75.8153 - val_loss: 12221.2158 - val_mae: 86.6159
# Epoch 3/50
# 1770/1773 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7784.4951 - mae: 69.5656
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 1773/1773 ━━━━━━━━━━━━━━━━━━━━ 17s 9ms/step - loss: 7784.3726 - mae: 69.5652 - val_loss: 11149.5986 - val_mae: 81.8268
# Epoch 4/50
# 1772/1773 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 7204.8960 - mae: 66.5938
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 1773/1773 ━━━━━━━━━━━━━━━━━━━━ 17s 9ms/step - loss: 7204.5713 - mae: 66.5920 - val_loss: 10190.9609 - val_mae: 77.6095
# Epoch 5/50
# 1769/1773 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6383.8154 - mae: 62.2744
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 1773/1773 ━━━━━━━━━━━━━━━━━━━━ 17s 10ms/step - loss: 6383.2900 - mae: 62.2714 - val_loss: 9325.0791 - val_mae: 73.8543
# Epoch 6/50
# 1770/1773 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 5744.1050 - mae: 58.8133
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 1773/1773 ━━━━━━━━━━━━━━━━━━━━ 33s 18ms/step - loss: 5743.7188 - mae: 58.8113 - val_loss: 8560.5264 - val_mae: 70.5988
# Epoch 7/50
# 1768/1773 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5217.2900 - mae: 56.1506
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 1773/1773 ━━━━━━━━━━━━━━━━━━━━ 17s 9ms/step - loss: 5216.6963 - mae: 56.1475 - val_loss: 7892.2681 - val_mae: 67.8144
# Epoch 8/50
# 1773/1773 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4698.5854 - mae: 53.4819
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 1773/1773 ━━━━━━━━━━━━━━━━━━━━ 17s 9ms/step - loss: 4698.5317 - mae: 53.4816 - val_loss: 7322.6860 - val_mae: 65.5027
# Epoch 9/50
# 1772/1773 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4413.8682 - mae: 52.1648
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 1773/1773 ━━━━━━━━━━━━━━━━━━━━ 17s 9ms/step - loss: 4413.6865 - mae: 52.1639 - val_loss: 6850.8481 - val_mae: 63.6513
# Epoch 10/50
# 1769/1773 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3969.0413 - mae: 49.9594
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 1773/1773 ━━━━━━━━━━━━━━━━━━━━ 17s 9ms/step - loss: 3969.0754 - mae: 49.9596 - val_loss: 6356.3999 - val_mae: 60.8863
# Epoch 11/50
# 1769/1773 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3296.8896 - mae: 41.9062
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 1773/1773 ━━━━━━━━━━━━━━━━━━━━ 17s 10ms/step - loss: 3296.3972 - mae: 41.8986 - val_loss: 5377.8521 - val_mae: 51.1946
# Epoch 12/50
# 1770/1773 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2749.9541 - mae: 35.5343
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 1773/1773 ━━━━━━━━━━━━━━━━━━━━ 16s 9ms/step - loss: 2749.7712 - mae: 35.5323 - val_loss: 4801.6270 - val_mae: 46.4676
# Epoch 13/50
# 1767/1773 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2371.3230 - mae: 32.1293
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 1773/1773 ━━━━━━━━━━━━━━━━━━━━ 16s 9ms/step - loss: 2371.1802 - mae: 32.1278 - val_loss: 4345.1719 - val_mae: 43.5381
# Epoch 14/50
# 1768/1773 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2145.8252 - mae: 30.0479
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 1773/1773 ━━━━━━━━━━━━━━━━━━━━ 17s 10ms/step - loss: 2145.5454 - mae: 30.0460 - val_loss: 3966.0281 - val_mae: 41.2467
# Epoch 15/50
# 1772/1773 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1881.7546 - mae: 27.8570
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 1773/1773 ━━━━━━━━━━━━━━━━━━━━ 16s 9ms/step - loss: 1881.6906 - mae: 27.8565 - val_loss: 3601.4624 - val_mae: 39.1781
# Epoch 16/50
# 1771/1773 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1632.8909 - mae: 26.1257
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 1773/1773 ━━━━━━━━━━━━━━━━━━━━ 16s 9ms/step - loss: 1632.8945 - mae: 26.1253 - val_loss: 3286.2874 - val_mae: 37.1049
# Epoch 17/50
# 1770/1773 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1545.1437 - mae: 25.1163
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 1773/1773 ━━━━━━━━━━━━━━━━━━━━ 17s 10ms/step - loss: 1544.9973 - mae: 25.1152 - val_loss: 3128.1987 - val_mae: 36.1320
# Epoch 18/50
# 1769/1773 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1382.4918 - mae: 23.7460
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 1773/1773 ━━━━━━━━━━━━━━━━━━━━ 17s 10ms/step - loss: 1382.3765 - mae: 23.7449 - val_loss: 2808.7380 - val_mae: 34.3182
# Epoch 19/50
# 1772/1773 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1283.7468 - mae: 22.9403
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 1773/1773 ━━━━━━━━━━━━━━━━━━━━ 17s 10ms/step - loss: 1283.6884 - mae: 22.9397 - val_loss: 2597.3164 - val_mae: 32.6728
# Epoch 20/50
# 1770/1773 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1163.6075 - mae: 21.8652
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 1773/1773 ━━━━━━━━━━━━━━━━━━━━ 18s 10ms/step - loss: 1163.5627 - mae: 21.8646 - val_loss: 2538.9363 - val_mae: 32.0645
# Epoch 21/50
# 1770/1773 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1110.6438 - mae: 21.2183
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 1773/1773 ━━━━━━━━━━━━━━━━━━━━ 17s 10ms/step - loss: 1110.5505 - mae: 21.2174 - val_loss: 2277.9758 - val_mae: 30.9496
# Epoch 22/50
# 1771/1773 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1042.9102 - mae: 20.7073
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 1773/1773 ━━━━━━━━━━━━━━━━━━━━ 17s 10ms/step - loss: 1042.8623 - mae: 20.7068 - val_loss: 2179.1479 - val_mae: 30.4631
# Epoch 23/50
# 1773/1773 ━━━━━━━━━━━━━━━━━━━━ 19s 11ms/step - loss: 958.0337 - mae: 20.0620 - val_loss: 2200.3147 - val_mae: 29.7372
# Epoch 24/50
# 1769/1773 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 961.1760 - mae: 19.9539
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 1773/1773 ━━━━━━━━━━━━━━━━━━━━ 18s 10ms/step - loss: 961.0707 - mae: 19.9529 - val_loss: 2054.3638 - val_mae: 29.1078
# Epoch 25/50
# 1770/1773 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 898.6992 - mae: 19.4807
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 1773/1773 ━━━━━━━━━━━━━━━━━━━━ 16s 9ms/step - loss: 898.6978 - mae: 19.4806 - val_loss: 1939.7754 - val_mae: 29.4392
# Epoch 26/50
# 1773/1773 ━━━━━━━━━━━━━━━━━━━━ 17s 10ms/step - loss: 890.7247 - mae: 19.3030 - val_loss: 2025.3651 - val_mae: 28.8116
# Epoch 27/50
# 1773/1773 ━━━━━━━━━━━━━━━━━━━━ 17s 10ms/step - loss: 842.4774 - mae: 18.8525 - val_loss: 2045.5370 - val_mae: 28.6629
# Epoch 28/50
# 1773/1773 ━━━━━━━━━━━━━━━━━━━━ 17s 9ms/step - loss: 812.7029 - mae: 18.4584 - val_loss: 1944.4884 - val_mae: 27.7180
# Epoch 29/50
# 1773/1773 ━━━━━━━━━━━━━━━━━━━━ 17s 9ms/step - loss: 828.4599 - mae: 18.6183 - val_loss: 2040.6914 - val_mae: 28.1795
# Epoch 30/50
# 1767/1773 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 781.8143 - mae: 18.2241
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 1773/1773 ━━━━━━━━━━━━━━━━━━━━ 17s 10ms/step - loss: 781.8621 - mae: 18.2248 - val_loss: 1822.3398 - val_mae: 27.7460
# Epoch 31/50
# 1773/1773 ━━━━━━━━━━━━━━━━━━━━ 18s 10ms/step - loss: 765.3837 - mae: 18.0682 - val_loss: 1882.3197 - val_mae: 27.4462
# Epoch 32/50
# 1773/1773 ━━━━━━━━━━━━━━━━━━━━ 17s 9ms/step - loss: 761.6484 - mae: 18.0554 - val_loss: 1862.5367 - val_mae: 27.1264
# Epoch 33/50
# 1773/1773 ━━━━━━━━━━━━━━━━━━━━ 16s 9ms/step - loss: 781.1298 - mae: 18.2274 - val_loss: 1918.4720 - val_mae: 27.4007
# Epoch 34/50
# 1773/1773 ━━━━━━━━━━━━━━━━━━━━ 16s 9ms/step - loss: 740.2331 - mae: 17.8964 - val_loss: 2024.2466 - val_mae: 27.8236
# Epoch 35/50
# 1773/1773 ━━━━━━━━━━━━━━━━━━━━ 17s 9ms/step - loss: 728.1582 - mae: 17.6841 - val_loss: 1884.3635 - val_mae: 27.4828
# Epoch 36/50
# 1773/1773 ━━━━━━━━━━━━━━━━━━━━ 17s 9ms/step - loss: 703.9540 - mae: 17.4145 - val_loss: 1924.1729 - val_mae: 27.8519
# Epoch 37/50
# 1766/1773 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 751.7607 - mae: 17.7941
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 1773/1773 ━━━━━━━━━━━━━━━━━━━━ 16s 9ms/step - loss: 751.6030 - mae: 17.7931 - val_loss: 1654.7502 - val_mae: 27.2968
# Epoch 38/50
# 1773/1773 ━━━━━━━━━━━━━━━━━━━━ 17s 9ms/step - loss: 703.3229 - mae: 17.4228 - val_loss: 1785.7544 - val_mae: 27.2179
# Epoch 39/50
# 1773/1773 ━━━━━━━━━━━━━━━━━━━━ 17s 9ms/step - loss: 719.8366 - mae: 17.6487 - val_loss: 1785.0421 - val_mae: 27.6329
# Epoch 40/50
# 1773/1773 ━━━━━━━━━━━━━━━━━━━━ 17s 9ms/step - loss: 667.5367 - mae: 17.0026 - val_loss: 1893.9723 - val_mae: 27.7306
# Epoch 41/50
# 1773/1773 ━━━━━━━━━━━━━━━━━━━━ 17s 9ms/step - loss: 681.1962 - mae: 17.2349 - val_loss: 1723.7295 - val_mae: 26.2484
# Epoch 42/50
# 1773/1773 ━━━━━━━━━━━━━━━━━━━━ 17s 10ms/step - loss: 701.8918 - mae: 17.4784 - val_loss: 1898.5129 - val_mae: 26.8930
# Epoch 43/50
# 1773/1773 ━━━━━━━━━━━━━━━━━━━━ 17s 10ms/step - loss: 662.2876 - mae: 16.9912 - val_loss: 1835.9486 - val_mae: 26.3006
# Epoch 44/50
# 1773/1773 ━━━━━━━━━━━━━━━━━━━━ 17s 9ms/step - loss: 658.6218 - mae: 17.0021 - val_loss: 1837.7948 - val_mae: 26.4268
# Epoch 45/50
# 1773/1773 ━━━━━━━━━━━━━━━━━━━━ 17s 9ms/step - loss: 643.7927 - mae: 16.7055 - val_loss: 1903.3488 - val_mae: 27.6983
# Epoch 46/50
# 1773/1773 ━━━━━━━━━━━━━━━━━━━━ 18s 10ms/step - loss: 643.1103 - mae: 16.8489 - val_loss: 1851.4330 - val_mae: 26.5447
# Epoch 47/50
# 1773/1773 ━━━━━━━━━━━━━━━━━━━━ 17s 10ms/step - loss: 620.0696 - mae: 16.5513 - val_loss: 1837.5667 - val_mae: 26.9673
# Epoch 48/50
# 1773/1773 ━━━━━━━━━━━━━━━━━━━━ 18s 10ms/step - loss: 630.8707 - mae: 16.6035 - val_loss: 1889.9761 - val_mae: 27.6724
# Epoch 49/50
# 1773/1773 ━━━━━━━━━━━━━━━━━━━━ 18s 10ms/step - loss: 654.2512 - mae: 16.8034 - val_loss: 1895.8220 - val_mae: 27.1521
# Epoch 50/50
# 1773/1773 ━━━━━━━━━━━━━━━━━━━━ 17s 10ms/step - loss: 593.8513 - mae: 16.1948 - val_loss: 1899.8494 - val_mae: 28.4310
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 228ms/step
# 2025/07/17 12:03:51 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 2025/07/17 12:04:02 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 2025/07/17 12:04:02 WARNING mlflow.keras.save: You are saving a Keras model without specifying model signature.
# 2025/07/17 12:04:11 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[14], line 28
#      24     print("💾 Model saved as 'expr_LSTM_023y.h5")
#      27 if __name__ == "__main__":
# ---> 28     main()
#
# Cell In[14], line 21, in main()
#      18 print("🚀 Training LSTM model_01 with asymmetric PHM08 loss...")
#      19 history = train_model(model, X, y)
# ---> 21 plot_loss(history)
#      23 model.save("expr_LSTM_023y.h5")
#      24 print("💾 Model saved as 'expr_LSTM_023y.h5")
#
# File d:\turbofan_RUL\Turbofan-Engine-Remaining_Useful_Life\utils.py:91, in plot_loss(history)
#      90 def plot_loss(history):
# ---> 91     plt.plot(history.history["loss"], label="Train Loss")
#      92     plt.plot(history.history["val_loss"], label="Val Loss")
#      93     plt.xlabel("Epochs")
#
# AttributeError: 'tuple' object has no attribute 'history'

# %%
def linear_LSTM_model_base(input_shape):
    model = Sequential()
    model.add(Dense(64, input_shape=input_shape, output_shape=input_shape))
    model.add(Dropout(0.25))
    model.add(LSTM(32, return_sequences=True, input_shape=input_shape))
    model.add(Dropout(0.215))

    model.add(Dense(1))
    model.compile(
        optimizer=SVG(learning_rate=0.000125),
        loss=asymmetric_loss,
        metrics=[
            tf.keras.metrics.MeanAbsoluteError(),
            tf.keras.metrics.LogCoshError(),
            tf.keras.metrics.MeanSquaredError(),
            tf.keras.metrics.R2Score(),
        ],
    )
    return model

# %%
def main():

    print("📥 Loading data...")
    df = load_and_preprocess_data(DATA_PATH)

    feature_columns = OP_COLS + SENSOR_COLS
    df, scaler = normalize(df, feature_columns)

    print("🔁 Creating sequences...")
    X, y = create_sequences(df, SEQUENCE_LENGTH, feature_columns)

    print(f"✅ Input shape to LSTM: {X.shape}")  # Should be (samples, 30, features)
    print(f"✅ Target shape: {y.shape}")  # Should be (samples, 1)

    model = linear_LSTM_model_base(input_shape=(SEQUENCE_LENGTH, len(feature_columns)))
    model.summary()

    print("🚀 Training LSTM model_01 with asymmetric PHM08 loss...")
    history = train_model(model, X, y)

    plot_loss(history)

    model.save("Linear_lstm_base.h5")
    print("💾 Model saved as 'Linear_lstm_base.h5")


if __name__ == "__main__":
    main()
# Out:
# 📥 Loading data...
# 🔁 Creating sequences...
# ✅ Input shape to LSTM: (17731, 30, 24)
# ✅ Target shape: (17731, 1)
# d:\turbofan_RUL\Turbofan-Engine-Remaining_Useful_Life\tf_rul\lib\site-packages\keras\src\layers\core\dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[20], line 28
#      24     print("💾 Model saved as 'Linear_lstm_base.h5")
#      27 if __name__ == "__main__":
# ---> 28     main()
#
# Cell In[20], line 15, in main()
#      12 print(f"✅ Input shape to LSTM: {X.shape}")  # Should be (samples, 30, features)
#      13 print(f"✅ Target shape: {y.shape}")  # Should be (samples, 1)
# ---> 15 model = linear_LSTM_model_base(input_shape=(SEQUENCE_LENGTH, len(feature_columns)))
#      16 model.summary()
#      18 print("🚀 Training LSTM model_01 with asymmetric PHM08 loss...")
#
# Cell In[19], line 3, in linear_LSTM_model_base(input_shape)
#       1 def linear_LSTM_model_base(input_shape):
#       2     model = Sequential()
# ----> 3     model.add(Dense(64, input_shape = input_shape, output_shape = input_shape))
#       4     model.add(Dropout(0.25))
#       5     model.add(LSTM(32, return_sequences= True, input_shape = input_shape))
#
# File d:\turbofan_RUL\Turbofan-Engine-Remaining_Useful_Life\tf_rul\lib\site-packages\keras\src\layers\core\dense.py:93, in Dense.__init__(self, units, activation, use_bias, kernel_initializer, bias_initializer, kernel_regularizer, bias_regularizer, activity_regularizer, kernel_constraint, bias_constraint, lora_rank, lora_alpha, **kwargs)
#      77 def __init__(
#      78     self,
#      79     units,
#    (...)
#      91     **kwargs,
#      92 ):
# ---> 93     super().__init__(activity_regularizer=activity_regularizer, **kwargs)
#      94     self.units = units
#      95     self.activation = activations.get(activation)
#
# File d:\turbofan_RUL\Turbofan-Engine-Remaining_Useful_Life\tf_rul\lib\site-packages\keras\src\layers\layer.py:291, in Layer.__init__(self, activity_regularizer, trainable, dtype, autocast, name, **kwargs)
#     289     self._input_shape_arg = input_shape_arg
#     290 if kwargs:
# --> 291     raise ValueError(
#     292         "Unrecognized keyword arguments "
#     293         f"passed to {self.__class__.__name__}: {kwargs}"
#     294     )
#     296 self._path = None  # Will be determined in `build_wrapper`
#     297 self.built = False
#
# ValueError: Unrecognized keyword arguments passed to Dense: {'output_shape': (30, 24)}
